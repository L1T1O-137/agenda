# %%
from django.db import connection, reset_queries
import time
tempo_inicio = time.time()
produtos = Produto.objects.all()
tempo_fim = time.time()
duracao = tempo_fim - tempo_inicio
print(f'Executou {len(connection.queries)} consultas')
print(f'Tempo de execução: {round(duracao, 3)} segundos')
reset_queries()
# Out:
# Executou 0 consultas
# Tempo de execução: 0.0 segundos

# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from django.db import connection, reset_queries
import time
tempo_inicio = time.time()
produtos = Produto.objects.all()
for p in produtos:
    pass
tempo_fim = time.time()
duracao = tempo_fim - tempo_inicio
print(f'Executou {len(connection.queries)} consultas')
print(f'Tempo de execução: {round(duracao, 3)} segundos')
reset_queries()
# Out:
# Executou 1 consultas
# Tempo de execução: 0.027 segundos
